# %%
# !pip install -U ragatouille FlagEmbedding
# Out:
# ...
#   Using cached ragatouille-0.0.8.post2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached colbert_ai-0.2.19-py3-none-any.whl
# ...
#   Using cached faiss_cpu-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.6 kB)
# ...
#   Using cached fast_pytorch_kmeans-0.2.0.1-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached onnx-1.16.0-cp311-cp311-macosx_10_15_universal2.whl.metadata (16 kB)
# ...
#   Using cached srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 140.2 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached voyager-2.0.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.9 kB)
# ...
#   Using cached bitarray-2.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# ...
#   Using cached git_python-1.0.3-py2.py3-none-any.whl.metadata (331 bytes)
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# ...
